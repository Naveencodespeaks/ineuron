# %%
import pandas as pd

# %%
# read_excel is used to read the data or  load the excel data
df = pd.read_excel(r'C:\Users\Naveen\Downloads\data sets\Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
pd.read_csv(r'C:\Users\Naveen\Downloads\data sets\haberman.csv',header = None,)
# Out:
#       0   1  2  3
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
pd.read_csv(r'C:\Users\Naveen\Downloads\data sets\haberman.csv',header = None)
# Out:
#       0   1  2  3
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
# here we are using names = ['Age', "Patient's year of operation ","Number of positive","Survival status"]
pd.read_csv(r'C:\Users\Naveen\Downloads\data sets\haberman.csv',header = None,names = ['Age ', "Patient's year of operation ","Number of positive","Survival status"])
# Out:
#      Age   Patient's year of operation   Number of positive  Survival status
# 0      30                            64                   1                1
# 1      30                            62                   3                1
# 2      30                            65                   0                1
# 3      31                            59                   2                1
# 4      31                            65                   4                1
# ..    ...                           ...                 ...              ...
# 301    75                            62                   1                1
# 302    76                            67                   0                1
# 303    77                            65                   3                1
# 304    78                            65                   1                2
# 305    83                            58                   2                2
#
# [306 rows x 4 columns]

# %%
# here we performed the , to @
pd.read_csv(r'C:\Users\Naveen\Downloads\data sets\haberman1.csv')
# Out:
#       30@64@1@1
# 0     30@62@3@1
# 1     30@65@0@1
# 2     31@59@2@1
# 3     31@65@4@1
# 4    33@58@10@1
# ..          ...
# 912   75@62@1@1
# 913   76@67@0@1
# 914   77@65@3@1
# 915   78@65@1@2
# 916   83@58@2@2
#
# [917 rows x 1 columns]

# %%
# here delimeter @ and performing seperations
pd.read_csv(r'C:\Users\Naveen\Downloads\data sets\haberman1.csv',sep= '@')
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 912  75  62   1    1
# 913  76  67   0    1
# 914  77  65   3    1
# 915  78  65   1    2
# 916  83  58   2    2
#
# [917 rows x 4 columns]

# %%
# we can read the csv data from github repo by clicking raw and coping the raw url and past init we can able to read github data as well.
pd.read_csv(r'https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %% [markdown]
# # here we are reading data from website using read_html
# # we can read the data only avaliable in tabular formate

# %%
pd.read_html(r'https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# here we are reading data from website using read_html
a = pd.read_html(r'https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
# we are performing the json viewer by read_json

js = pd.read_json(r'https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
len('user')
# Out:
# 4

# %%
js['user'][0]
# Out:
# {'login': 'mroeschke',
#  'id': 10647082,
#  'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/mroeschke',
#  'html_url': 'https://github.com/mroeschke',
#  'followers_url': 'https://api.github.com/users/mroeschke/followers',
#  'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#  'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#  'repos_url': 'https://api.github.com/users/mroeschke/repos',
#  'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#  'type': 'User',
# ...

# %%
js['user'][1]
# Out:
# {'login': 'mroeschke',
#  'id': 10647082,
#  'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/mroeschke',
#  'html_url': 'https://github.com/mroeschke',
#  'followers_url': 'https://api.github.com/users/mroeschke/followers',
#  'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#  'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#  'repos_url': 'https://api.github.com/users/mroeschke/repos',
#  'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#  'type': 'User',
# ...

# %%
js['user'][2]
# Out:
# {'login': 'rchen152',
#  'id': 4142312,
#  'node_id': 'MDQ6VXNlcjQxNDIzMTI=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/4142312?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/rchen152',
#  'html_url': 'https://github.com/rchen152',
#  'followers_url': 'https://api.github.com/users/rchen152/followers',
#  'following_url': 'https://api.github.com/users/rchen152/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/rchen152/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/rchen152/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/rchen152/subscriptions',
#  'organizations_url': 'https://api.github.com/users/rchen152/orgs',
#  'repos_url': 'https://api.github.com/users/rchen152/repos',
#  'events_url': 'https://api.github.com/users/rchen152/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/rchen152/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
js['user'][3]
# Out:
# {'login': 'kvn4',
#  'id': 55560840,
#  'node_id': 'MDQ6VXNlcjU1NTYwODQw',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/55560840?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/kvn4',
#  'html_url': 'https://github.com/kvn4',
#  'followers_url': 'https://api.github.com/users/kvn4/followers',
#  'following_url': 'https://api.github.com/users/kvn4/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/kvn4/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/kvn4/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/kvn4/subscriptions',
#  'organizations_url': 'https://api.github.com/users/kvn4/orgs',
#  'repos_url': 'https://api.github.com/users/kvn4/repos',
#  'events_url': 'https://api.github.com/users/kvn4/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/kvn4/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
js['user'][4]
# Out:
# {'login': 'DeaMariaLeon',
#  'id': 11835246,
#  'node_id': 'MDQ6VXNlcjExODM1MjQ2',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/DeaMariaLeon',
#  'html_url': 'https://github.com/DeaMariaLeon',
#  'followers_url': 'https://api.github.com/users/DeaMariaLeon/followers',
#  'following_url': 'https://api.github.com/users/DeaMariaLeon/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/DeaMariaLeon/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/DeaMariaLeon/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/DeaMariaLeon/subscriptions',
#  'organizations_url': 'https://api.github.com/users/DeaMariaLeon/orgs',
#  'repos_url': 'https://api.github.com/users/DeaMariaLeon/repos',
#  'events_url': 'https://api.github.com/users/DeaMariaLeon/events{/privacy}',
# ...

# %%
df= pd.read_excel(r'C:\Users\Naveen\Downloads\data sets\Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %% [markdown]
# # converting excel to js

# %%
df.to_json('converted_Excel_To_Json.json')

# %% [markdown]
# ## pwd stands for present directory

# %%
pwd
# Out:
# 'C:\\Users\\Naveen'

# %% [markdown]
# # storing a data

# %%
df= pd.read_json(r'C:\Users\Naveen\Downloads\data sets\Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           None     chiffon     ruffles
# ...

# %%
# this converted data is stored in the d drive
df.to_csv('E:\\converted_excel123.csv',sep= '#')

# %%
# this converted data is stored in the d drive and sepraating with #
df.to_csv('E:\\converted_excel123.csv',sep= '#')

# %%
df.to_csv('E:\\converted_excel1234.csv',sep= '#',index = False)

# %%
df= pd.read_excel(r'C:\Users\Naveen\Downloads\data sets\Attribute DataSet.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9968\2328400251.py in <module>
# ----> 1 df= pd.read_excel(r'C:\Users\Naveen\Downloads\data sets\Attribute DataSet.xlsx')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
df.to_excel(r'C:\Users\Naveen\Downloads\data sets\Attribute DataSet.xlsx')

# %%
df= pd.read_excel(r'C:\Users\Naveen\Downloads\data sets\Attribute DataSet.xlsx')

# %%
df
# Out:
#      Unnamed: 0    Dress_ID    Style    Price  Rating  Size  Season  \
# 0             0  1006032852     Sexy      Low     4.6     M  Summer
# 1             1  1212192089   Casual      Low     0.0     L  Summer
# 2             2  1190380701  vintage     High     0.0     L  Automn
# 3             3   966005983    Brief  Average     4.6     L  Spring
# 4             4   876339541     cute      Low     4.5     M  Summer
# ..          ...         ...      ...      ...     ...   ...     ...
# 495         495   713391965   Casual      Low     4.7     M  Spring
# 496         496   722565148     Sexy      Low     4.3  free  Summer
# 497         497   532874347   Casual  Average     4.7     M  Summer
# 498         498   655464934   Casual  Average     4.6     L  winter
# 499         499   919930954   Casual      Low     4.4  free  Summer
#
#       NeckLine SleeveLength waiseline       Material  FabricType  Decoration  \
# ...
