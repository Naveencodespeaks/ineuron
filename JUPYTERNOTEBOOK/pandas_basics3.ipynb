# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Naveen\Downloads\data sets\FitBit data.csv')

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
data = {'name':['sudh', 'krish','hitesh','tulesko'],
        'salary' : [100,200,300,400],
        'mail_id': ['sudh@ineuron.ai','krishn@ineuron','hitesh@ineuron.ai','tulesko@ineuron'],
        'addr': ['blr','blr','blr','mum']
}

# %%
data
# Out:
# {'name': ['sudh', 'krish', 'hitesh', 'tulesko'],
#  'salary': [100, 200, 300, 400],
#  'mail_id': ['sudh@ineuron.ai',
#   'krishn@ineuron',
#   'hitesh@ineuron.ai',
#   'tulesko@ineuron'],
#  'addr': ['blr', 'blr', 'blr', 'mum']}

# %%
pd.DataFrame(data)
# Out:
#       name  salary            mail_id addr
# 0     sudh     100    sudh@ineuron.ai  blr
# 1    krish     200     krishn@ineuron  blr
# 2   hitesh     300  hitesh@ineuron.ai  blr
# 3  tulesko     400    tulesko@ineuron  mum

# %%
pd.DataFrame(data,columns= [1,2,3])
# Out:
# Empty DataFrame
# Columns: [1, 2, 3]
# Index: []

# %%
pd.DataFrame(data,index = [4,5,6,7])
# Out:
#       name  salary            mail_id addr
# 4     sudh     100    sudh@ineuron.ai  blr
# 5    krish     200     krishn@ineuron  blr
# 6   hitesh     300  hitesh@ineuron.ai  blr
# 7  tulesko     400    tulesko@ineuron  mum

# %%
df = pd.DataFrame(data,index = [4,5,6,7])

# %%
df
# Out:
#       name  salary            mail_id addr
# 4     sudh     100    sudh@ineuron.ai  blr
# 5    krish     200     krishn@ineuron  blr
# 6   hitesh     300  hitesh@ineuron.ai  blr
# 7  tulesko     400    tulesko@ineuron  mum

# %%
df.loc[5:6]
# Out:
#      name  salary            mail_id addr
# 5   krish     200     krishn@ineuron  blr
# 6  hitesh     300  hitesh@ineuron.ai  blr

# %%
df.iloc[1:3]
# Out:
#      name  salary            mail_id addr
# 5   krish     200     krishn@ineuron  blr
# 6  hitesh     300  hitesh@ineuron.ai  blr

# %%
df.loc[5:6]
# Out:
#      name  salary            mail_id addr
# 5   krish     200     krishn@ineuron  blr
# 6  hitesh     300  hitesh@ineuron.ai  blr

# %%
# here we are assigning the new values to the index 
# we can add index values as well by performing index =[data,data, data,.....etc]
df= pd.DataFrame(data,index= ['sudh','krish','hitesh','tulesuko'])

# %%
df
# Out:
#              name  salary            mail_id addr
# sudh         sudh     100    sudh@ineuron.ai  blr
# krish       krish     200     krishn@ineuron  blr
# hitesh     hitesh     300  hitesh@ineuron.ai  blr
# tulesuko  tulesko     400    tulesko@ineuron  mum

# %%
df= pd.DataFrame(data,index= [0,1,2,3])

# %%
df
# Out:
#       name  salary            mail_id addr
# 0     sudh     100    sudh@ineuron.ai  blr
# 1    krish     200     krishn@ineuron  blr
# 2   hitesh     300  hitesh@ineuron.ai  blr
# 3  tulesko     400    tulesko@ineuron  mum

# %%
data1 = {
    
    'pf_num':[2341,23,42,4221,],
    'income_tax':[234,34,34,532],
    'mobile_no':[1234,342,34,344],
    'courses':['ds','bigdata','web dev','block_chain']
}

# %%
data1
# Out:
# {'pf_num': [2341, 23, 42, 4221],
#  'income_tax': [234, 34, 34, 532],
#  'mobile_no': [1234, 342, 34, 344],
#  'courses': ['ds', 'bigdata', 'web dev', 'block_chain']}

# %%
df1 = pd.DataFrame(data1)

# %%
df1
# Out:
#    pf_num  income_tax  mobile_no      courses
# 0    2341         234       1234           ds
# 1      23          34        342      bigdata
# 2      42          34         34      web dev
# 3    4221         532        344  block_chain

# %% [markdown]
# # in concatination we have two types {vertical_concatination,horizontal-concatination}

# %%
# Here we are performing vertical concatination operations
pd.concat([df,df1])
# Out:
#       name  salary            mail_id addr  pf_num  income_tax  mobile_no  \
# 0     sudh   100.0    sudh@ineuron.ai  blr     NaN         NaN        NaN
# 1    krish   200.0     krishn@ineuron  blr     NaN         NaN        NaN
# 2   hitesh   300.0  hitesh@ineuron.ai  blr     NaN         NaN        NaN
# 3  tulesko   400.0    tulesko@ineuron  mum     NaN         NaN        NaN
# 0      NaN     NaN                NaN  NaN  2341.0       234.0     1234.0
# 1      NaN     NaN                NaN  NaN    23.0        34.0      342.0
# 2      NaN     NaN                NaN  NaN    42.0        34.0       34.0
# 3      NaN     NaN                NaN  NaN  4221.0       532.0      344.0
#
#        courses
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 0           ds
# 1      bigdata
# 2      web dev
# 3  block_chain

# %%
# axis=1 means you have to perform column wise operations (horizontal operation)
# The is the meaning of axis=1 
pd.concat([df,df1], axis = 1)
# Out:
#       name  salary            mail_id addr  pf_num  income_tax  mobile_no  \
# 0     sudh     100    sudh@ineuron.ai  blr    2341         234       1234
# 1    krish     200     krishn@ineuron  blr      23          34        342
# 2   hitesh     300  hitesh@ineuron.ai  blr      42          34         34
# 3  tulesko     400    tulesko@ineuron  mum    4221         532        344
#
#        courses
# 0           ds
# 1      bigdata
# 2      web dev
# 3  block_chain

# %%
# axis=0 means you have to perform row wise operations(vertical operations)
# The is the meaning of axis=0 
pd.concat([df,df1], axis = 0)
# Out:
#       name  salary            mail_id addr  pf_num  income_tax  mobile_no  \
# 0     sudh   100.0    sudh@ineuron.ai  blr     NaN         NaN        NaN
# 1    krish   200.0     krishn@ineuron  blr     NaN         NaN        NaN
# 2   hitesh   300.0  hitesh@ineuron.ai  blr     NaN         NaN        NaN
# 3  tulesko   400.0    tulesko@ineuron  mum     NaN         NaN        NaN
# 0      NaN     NaN                NaN  NaN  2341.0       234.0     1234.0
# 1      NaN     NaN                NaN  NaN    23.0        34.0      342.0
# 2      NaN     NaN                NaN  NaN    42.0        34.0       34.0
# 3      NaN     NaN                NaN  NaN  4221.0       532.0      344.0
#
#        courses
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 0           ds
# 1      bigdata
# 2      web dev
# 3  block_chain

# %%
data2 = {'0':['sudh', 'krish','hitesh','tulesko'],
        '1' : [100,200,300,400],
        '2': ['sudh@ineuron.ai','krishn@ineuron','hitesh@ineuron.ai','tulesko@ineuron'],
        '3': ['blr','blr','blr','mum']
}

# %%
data2
# Out:
# {'0': ['sudh', 'krish', 'hitesh', 'tulesko'],
#  '1': [100, 200, 300, 400],
#  '2': ['sudh@ineuron.ai',
#   'krishn@ineuron',
#   'hitesh@ineuron.ai',
#   'tulesko@ineuron'],
#  '3': ['blr', 'blr', 'blr', 'mum']}

# %%
data3 = {
    
    '0':[2341,23,42,4221],
    '1':[234,34,34,54],
    '2':[1234,342,34,45],
    '3':['ds','bigdata','web dev','block_chain']
}

# %%
data3
# Out:
# {'0': [2341, 23, 42, 4221],
#  '1': [234, 34, 34, 54],
#  '2': [1234, 342, 34, 45],
#  '3': ['ds', 'bigdata', 'web dev', 'block_chain']}

# %%
# Here we are conveting the set data into data_frame as df2
df2 = pd.DataFrame(data2)

# %%
df2
# Out:
#          0    1                  2    3
# 0     sudh  100    sudh@ineuron.ai  blr
# 1    krish  200     krishn@ineuron  blr
# 2   hitesh  300  hitesh@ineuron.ai  blr
# 3  tulesko  400    tulesko@ineuron  mum

# %%
# Here we are conveting the set data into data_frame as df3
df3 = pd.DataFrame(data3)

# %%
df3
# Out:
#       0    1     2            3
# 0  2341  234  1234           ds
# 1    23   34   342      bigdata
# 2    42   34    34      web dev
# 3  4221   54    45  block_chain

# %%
pd.concat([df2,df3])
# Out:
#          0    1                  2            3
# 0     sudh  100    sudh@ineuron.ai          blr
# 1    krish  200     krishn@ineuron          blr
# 2   hitesh  300  hitesh@ineuron.ai          blr
# 3  tulesko  400    tulesko@ineuron          mum
# 0     2341  234               1234           ds
# 1       23   34                342      bigdata
# 2       42   34                 34      web dev
# 3     4221   54                 45  block_chain

# %% [markdown]
# # merge operations

# %%
data4 = {'emp_id':[101,102,103,104],
         'salary':[234,4234,324,434],
         'pf': [23,32,42,54]
    
}

# %%
data5 = {
    'emp_id':[101,102,103,104],
    'mob_no':[34234,34332,3422,3435],
    'house_nu':[3342,34342,342,343]
}

# %%
df4 = pd.DataFrame(data4)

# %%
df5 = pd.DataFrame(data5)

# %%
df4
# Out:
#    emp_id  salary  pf
# 0     101     234  23
# 1     102    4234  32
# 2     103     324  42
# 3     104     434  54

# %%
df5
# Out:
#    emp_id  mob_no  house_nu
# 0     101   34234      3342
# 1     102   34332     34342
# 2     103    3422       342
# 3     104    3435       343

# %% [markdown]
# # merge operations = merge(data1,data2)
# #                                    merge(left, right)
# # inner merge operations
# # use Shift key and Tab to open string operation

# %%
pd.merge(df4,df5)
# Out:
#    emp_id  salary  pf  mob_no  house_nu
# 0     101     234  23   34234      3342
# 1     102    4234  32   34332     34342
# 2     103     324  42    3422       342
# 3     104     434  54    3435       343

# %%
pd.merge(df4,df5,how = 'left')
# Out:
#    emp_id  salary  pf  mob_no  house_nu
# 0     101     234  23   34234      3342
# 1     102    4234  32   34332     34342
# 2     103     324  42    3422       342
# 3     104     434  54    3435       343

# %%
pd.merge(df4,df5,how = 'right')
# Out:
#    emp_id  salary  pf  mob_no  house_nu
# 0     101     234  23   34234      3342
# 1     102    4234  32   34332     34342
# 2     103     324  42    3422       342
# 3     104     434  54    3435       343

# %%
pd.merge(df4,df5,how = 'right',on = 'emp_id')
# Out:
#    emp_id  salary  pf  mob_no  house_nu
# 0     101     234  23   34234      3342
# 1     102    4234  32   34332     34342
# 2     103     324  42    3422       342
# 3     104     434  54    3435       343

# %%
data6 = {'emp_id1':[101,102,103,104],
         'salary':[234,4234,324,434],
         'pf': [23,32,42,54]
    
}

# %%
data7 = {
    'emp_id2':[101,102,103,104],
    'mob_no':[34234,34332,3422,3435],
    'house_nu':[3342,34342,342,343]
}

# %%
df6 = pd.DataFrame(data6)

# %%
df7 = pd.DataFrame(data7)

# %%
df6
# Out:
#    emp_id1  salary  pf
# 0      101     234  23
# 1      102    4234  32
# 2      103     324  42
# 3      104     434  54

# %%
df7
# Out:
#    emp_id2  mob_no  house_nu
# 0      101   34234      3342
# 1      102   34332     34342
# 2      103    3422       342
# 3      104    3435       343

# %%
# No common columns to perform merge on. Merge options:
pd.merge(df6,df7)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11216\3324828827.py in <module>
#       1 # No common columns to perform merge on. Merge options:
# ----> 2 pd.merge(df6,df7)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     680             warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
#     681
# ...

# %%
pd.merge(df6,df7, left_on='emp_id1', right_on = 'emp_id2',how = 'inner')
# Out:
#    emp_id1  salary  pf  emp_id2  mob_no  house_nu
# 0      101     234  23      101   34234      3342
# 1      102    4234  32      102   34332     34342
# 2      103     324  42      103    3422       342
# 3      104     434  54      104    3435       343

# %%
data8 = {
    'emp_id':[101,102,103,102],
    'salary':[123,234,234,321],
    'pf':[23,43,44,33]
}

# %%
df8 = data8

# %%
df8
# Out:
# {'emp_id': [101, 102, 103, 102],
#  'salary': [123, 234, 234, 321],
#  'pf': [23, 43, 44, 33]}

# %%
data9 = {
    'emp_id':[101,102,103,102],
    'salary':[123,234,234,321],
    'house_nu':[345,443,443,343]
}

# %%
df8 = pd.DataFrame(data8)

# %%
df8
# Out:
#    emp_id  salary  pf
# 0     101     123  23
# 1     102     234  43
# 2     103     234  44
# 3     102     321  33

# %%
df9 = pd.DataFrame(data9)

# %%
df9
# Out:
#    emp_id  salary  house_nu
# 0     101     123       345
# 1     102     234       443
# 2     103     234       443
# 3     102     321       343

# %%
pd.merge(df8,df9)
# Out:
#    emp_id  salary  pf  house_nu
# 0     101     123  23       345
# 1     102     234  43       443
# 2     103     234  44       443
# 3     102     321  33       343

# %%
pd.merge(df8,df9,on = ['emp_id','salary'])
# Out:
#    emp_id  salary  pf  house_nu
# 0     101     123  23       345
# 1     102     234  43       443
# 2     103     234  44       443
# 3     102     321  33       343

# %% [markdown]
# # join operations

# %%
data9 = {
    'emp_id':[101,102,103,102],
    'salary':[123,234,234,321],
    'pf':[23,43,44,33]
}

# %%
data10 = {
    'emp_id1':[101,102,103,102],
    'salary1':[123,234,234,321],
    'pf':[345,443,443,343]
}

# %%
data11 = {
    'emp_id2':[101,102,103,102],
    'salary3':[123,234,234,321],
    'house_nu':[345,443,443,343]
}

# %%
df9 = pd.DataFrame(data9)

# %%
df10 = pd.DataFrame(data10)

# %%
df11 = pd.DataFrame(data11)

# %%
df9
# Out:
#    emp_id  salary  house_nu
# 0     101     123       345
# 1     102     234       443
# 2     103     234       443
# 3     102     321       343

# %%
df10
# Out:
#    emp_id1  salary1   pf
# 0      101      123  345
# 1      102      234  443
# 2      103      234  443
# 3      102      321  343

# %%
df11
# Out:
#    emp_id2  salary3  house_nu
# 0      101      123       345
# 1      102      234       443
# 2      103      234       443
# 3      102      321       343

# %%
df10 = pd.DataFrame(data10,index = ['a','b','c','d'])

# %%
df10
# Out:
#    emp_id1  salary1   pf
# a      101      123  345
# b      102      234  443
# c      103      234  443
# d      102      321  343

# %%
df11 = pd.DataFrame(data11,index = ['a','b','d','f'])

# %%
df11
# Out:
#    emp_id2  salary3  house_nu
# a      101      123       345
# b      102      234       443
# d      103      234       443
# f      102      321       343

# %%
df10.join(df11)
# Out:
#    emp_id1  salary1   pf  emp_id2  salary3  house_nu
# a      101      123  345    101.0    123.0     345.0
# b      102      234  443    102.0    234.0     443.0
# c      103      234  443      NaN      NaN       NaN
# d      102      321  343    103.0    234.0     443.0

# %%
pd.read_csv(r'C:\Users\Naveen\Downloads\data sets\sales_data_final.csv')
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df = pd.read_csv(r'C:\Users\Naveen\Downloads\data sets\sales_data_final.csv')

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Dra        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
def profit_flag(a):
    if a >= 0 :
        return 'positive'
    else:
        return 'negative'

# %%
profit_flag(-34)
# Out:
# 'negative'

# %%
df['flag_profit'] = df['profit'].apply(profit_flag)

# %%
df['flag_profit']
# Out:
# 0        positive
# 1        positive
# 2        positive
# 3        negative
# 4        positive
#            ...
# 51285    positive
# 51286    positive
# 51287    positive
# 51288    positive
# 51289    negative
# Name: flag_profit, Length: 51290, dtype: object

# %%
df['flag_profit'] = df['profit'].apply(profit_flag)

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sub_category  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      Storage
# 3  Home Office        Stockholm     Sweden      EU    North  ...        Paper
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  Furnishings
#
# ...

# %%
df['shipping_cost_checker']= df['shipping_cost'].apply(checker)

# %%
def checker(a):
    if a <= 100:
        return 'positive'
    else:
        return 'negative'

# %%
checker(300)
# Out:
# 'negative'

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#                   product_name sales quantity discount   profit  \
# 0          Tenex Lockers, Blue   408        2      0.0  106.140
# ...

# %%
df.head(20)
# Out:
#            order_id order_date ship_date       ship_mode      customer_name  \
# 0      AG-2011-2040   1/1/2011  1/6/2011  Standard Class    Toby Braunhardt
# 1     IN-2011-47883   1/1/2011  1/8/2011  Standard Class        Joseph Holt
# 2      HU-2011-1220   1/1/2011  1/5/2011    Second Class      Annie Thurman
# 3   IT-2011-3647632   1/1/2011  1/5/2011    Second Class       Eugene Moren
# 4     IN-2011-47883   1/1/2011  1/8/2011  Standard Class        Joseph Holt
# 5     IN-2011-47883   1/1/2011  1/8/2011  Standard Class        Joseph Holt
# 6      CA-2011-1510   1/2/2011  1/6/2011  Standard Class    Magdelene Morse
# 7     IN-2011-79397   1/3/2011  1/3/2011        Same Day        Kean Nguyen
# 8     ID-2011-80230   1/3/2011  1/9/2011  Standard Class       Ken Lonsdale
# 9      IZ-2011-4680   1/3/2011  1/7/2011  Standard Class   Lindsay Williams
# 10    IN-2011-65159   1/3/2011  1/7/2011    Second Class       Larry Blacks
# ...

# %%
def quantity_flag(a):
    if a < 10:
        return 'low'
    elif a> 10 and a< 20:
        return 'medium'
    else:
        return 'high'

# %%
df['quatity_flagg']=df['quantity'].apply(quantity_flag)

# %%
df.head(10)
# Out:
#           order_id order_date ship_date       ship_mode     customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class   Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class      Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 6     CA-2011-1510   1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7    IN-2011-79397   1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8    ID-2011-80230   1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9     IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
#
#        segment            state      country  market   region  ... sales  \
# 0     Consumer      Constantine      Algeria  Africa   Africa  ...   408
# ...

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['square_of_quatity'] = df['quantity'].apply(lambda a: a**2)

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
#
#   discount   profit shipping_cost order_priority  year  flag_profit  \
# ...
