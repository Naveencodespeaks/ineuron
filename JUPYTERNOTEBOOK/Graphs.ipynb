# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind = 'area')
# Out:
# <Axes: >

# %%
# alpha is a parameter to control the color
df.plot(kind = 'area', alpha = 0.1)
# Out:
# <Axes: >

# %%
# alpha is a parameter to control the color
df.plot(kind = 'area', alpha = 0.1, stacked = False)
# Out:
# <Axes: >

# %% [markdown]
# # scatter plot

# %%
df.plot.scatter(x = 'sepal_length', y = 'sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
# Here c is know as control or color
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Here c is known as control or color
# Here s is known as size
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 1000)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
# 
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = df['sepal_length']*20)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # Hexbin Graph

# %%
# gridsize means size of the dots
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 8)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
# gridsize means size of the dots
# cmap  means color mapping
# 'viridis' varient
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 10, cmap = 'viridis')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
from mpl_toolkits import mplot3d

# %%
x = np.linspace(-1,6,30)

# %%
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y = np.linspace(-1,7,30)

# %%
y
# Out:
# array([-1.        , -0.72413793, -0.44827586, -0.17241379,  0.10344828,
#         0.37931034,  0.65517241,  0.93103448,  1.20689655,  1.48275862,
#         1.75862069,  2.03448276,  2.31034483,  2.5862069 ,  2.86206897,
#         3.13793103,  3.4137931 ,  3.68965517,  3.96551724,  4.24137931,
#         4.51724138,  4.79310345,  5.06896552,  5.34482759,  5.62068966,
#         5.89655172,  6.17241379,  6.44827586,  6.72413793,  7.        ])

# %%
z = x+y

# %%
z
# Out:
# array([-2.        , -1.48275862, -0.96551724, -0.44827586,  0.06896552,
#         0.5862069 ,  1.10344828,  1.62068966,  2.13793103,  2.65517241,
#         3.17241379,  3.68965517,  4.20689655,  4.72413793,  5.24137931,
#         5.75862069,  6.27586207,  6.79310345,  7.31034483,  7.82758621,
#         8.34482759,  8.86206897,  9.37931034,  9.89655172, 10.4137931 ,
#        10.93103448, 11.44827586, 11.96551724, 12.48275862, 13.        ])

# %%
ax = plt.axes(projection = '3d')

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
z=x+y
ax = plt.axes(projection = '3d')# we are creating the white color dimenstions
ax.plot3D(x,y,z) # what ever the values of x,y,z will plot 
ax.set_xlabel('x') # lable means giving name:- Here we are setting the name of x_axis = x, 
ax.set_ylabel('y') # lable means giving name:- Here we are setting the name of y_axis = y, 
ax.set_zlabel('z') # lable means giving name:- Here we are setting the name of z_axis = z.
# Out:
# Text(0.5, 0, 'z')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
z=x+y
ax = plt.axes(projection = '3d')# we are creating the white color dimenstions
ax.plot3D(df["sepal_length"],df['sepal_width'],df['petal_length']) # what ever the values of x,y,z will plot 
ax.set_xlabel('sepal_length') # lable means giving name:- Here we are setting the name of x_axis = sepal_length, 
ax.set_ylabel('sepal_width') # lable means giving name:- Here we are setting the name of sepal_width, 
ax.set_zlabel('petal_length')# lable means giving name:- Here we are setting the name of petal_length,
# Out:
# Text(0.5, 0, 'petal_length')

# %%
df.plot(figsize = (20,10))
# Out:
# <Axes: >

# %% [markdown]
# # bar graph

# %%
df.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df.plot(kind = 'bar', figsize = (20,10))
# Out:
# <Axes: >

# %%
# we are selecting iloc so that it take the some of the integer level   vaues and plot us a graph
df.iloc[5:11].plot(kind = 'bar', figsize = (20,10))
# Out:
# <Axes: >

# %%
df.loc[5:11]# loc is used to give us the data or (retrive the data) based on rows and column lables
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa

# %%
df.iloc[5:11] # iloc checkes the by specifing the integer position of the data and give us the index numbers
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
# Here barh means Horizontal
# so basically it flip the graph
df.iloc[5:11].plot(kind = 'barh', figsize = (20,10))
# Out:
# <Axes: >

# %% [markdown]
# # important graph  ''Histogram''

# %%
# histogram basiclly tell us about the range and the frequency
# y = frequency
# x_axis = range
df.plot(kind='hist',figsize =(20,10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['sepal_length'].plot(kind= 'hist', figsize = (20,10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist(figsize = (20,10),color = 'red',alpha = 0.9)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df.hist(figsize = (20,10),color = 'grey',alpha = 0.9) # alpha is known as density
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
# !pip install cufflinks

# %%
import cufflinks as cf
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning:
#
# Blowfish has been deprecated

# %%
cf.go_offline() # we are going offline because so that we can execute the cufflinks
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="ab5b1f9d-9f4f-4a0d-833e-eb1a4216e701" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = 'sepal_length', y = 'sepal_width',kind = 'scatter', mode = 'markers')
# Out:
# <div>                            <div id="3b37938e-5aee-40a2-b167-b96885b93f35" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # bubble plot

# %%
df.iplot(x = 'sepal_length', y = 'sepal_width', kind = 'scatter', size = '12')
# Out:
# <div>                            <div id="f5d5d141-9909-45cb-81ed-405ebb1022a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = 'sepal_length', y = 'sepal_width', z ='petal_length', kind = 'bubble3d', size = 'sepal_length')
# Out:
# <div>                            <div id="acaaf7de-99e7-4738-ab7d-6818d906dafd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1 = sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df1.plot(x = 'total_bill',y = 'tip',kind = 'scatter')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df1.iplot(x = 'total_bill',y = 'tip',kind = 'scatter', mode = 'markers')
# Out:
# <div>                            <div id="df9f6734-cfec-4795-b96c-2a0c2424ddcd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.relplot(x = 'total_bill',y = 'tip', data = df1)

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
# hue create a groups based on the colors
sns.relplot(x = 'total_bill',y = 'tip', data = df1, hue = 'smoker')

# %%
sns.relplot(x = 'total_bill',y = 'tip', data = df1, hue = 'time')

# %%
sns.relplot(x = 'total_bill',y = 'tip', data = df1, hue = 'time',style = 'smoker')

# %%
# style and hue is just creating a grouping
sns.relplot(x = 'total_bill',y = 'tip', data = df1, hue = 'time',style = 'sex')

# %%
# style and hue is just creating a grouping
sns.relplot(x = 'total_bill',y = 'tip', data = df1, hue = 'size',style = 'sex')

# %%
sns.relplot(x = 'total_bill',y= 'tip',data = df1,col = 'time')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x = 'sepal_length',y= 'sepal_width',data = df,col = 'species')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = 'total_bill',y= 'tip',data = df1,col = 'day')

# %%
sns.catplot(x='day',y = 'total_bill',data = df1)

# %%
sns.pairplot(df1)

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(df)

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="8240ae8a-7718-433d-ac09-0d363d34872d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.scatter_matrix()
# Out:
# <div>                            <div id="850f6773-2f46-4fdb-a776-7d8c2694023d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.jointplot(x = df1.total_bill, y = df1.tip)

# %%
sns.jointplot(x = df1.total_bill, y = df1.tip, kind = 'hex')

# %%
sns.pairplot(df1)

# %%
sns.regplot(x = df1.total_bill, y = df1.tip)
sns.set(rc={'figure.figsize':(20,10)})

# %%
# go to seaborn documentation website we will go to gallary and select one of the graph

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Load the example car crash dataset
crashes = sns.load_dataset("car_crashes").sort_values("total", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="total", y="abbrev", data=crashes,
            label="Total", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="alcohol", y="abbrev", data=crashes,
            label="Alcohol-involved", color="b")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Automobile collisions per billion miles")
sns.despine(left=True, bottom=True)

# %%
crashes = sns.load_dataset("car_crashes")

# %%
crashes
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
import plotly.express as px
fig = px.scatter(df1,x = 'total_bill',y = 'tip',color= 'time')
fig.show()
# Out:
# <div>                            <div id="dc04e832-42ca-48fe-aec8-79391bc11c0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc04e832-42ca-48fe-aec8-79391bc11c0a")) {                    Plotly.newPlot(                        "dc04e832-42ca-48fe-aec8-79391bc11c0a",                        [{"hovertemplate":"time=Dinner<br>total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"Dinner","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Dinner","orientation":"v","showlegend":true,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.
# ...

# %%
import plotly.express as px
fig = px.bar(df1, x="sex", y="total_bill",color='smoker', barmode='group')
fig.show()
# Out:
# <div>                            <div id="44d7d0ef-bc69-44ca-9a65-e19d31ef0b72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44d7d0ef-bc69-44ca-9a65-e19d31ef0b72")) {                    Plotly.newPlot(                        "44d7d0ef-bc69-44ca-9a65-e19d31ef0b72",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>sex=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male
# ...
