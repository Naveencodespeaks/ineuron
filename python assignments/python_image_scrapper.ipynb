# %%
from flask import Flask,render_template, request, jsonify

# %%
# !conda install -c anaconda beautifulsoup4
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done

# %%
from bs4 import BeautifulSoup as bs

# %%
from urllib.request import urlopen as urReq

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "iphone13promax"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone13promax'

# %%
respose_website = urReq(flipkart_url)

# %%
respose_website

# %%
data_flipkart=respose_website.read()

# %%
beautifyed_html= bs(data_flipkart,"html.parser")

# %%
beautifyed_html
# Out:
# <!DOCTYPE html>
# ...

# %%
beautifyed_html.find_all("div",{"class" : "_1AtVbE"})
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone13promax&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?s
# ...

# %%
len(beautifyed_html.find_all("div",{"class" : "_1AtVbE"}))
# Out:
# 31

# %%
bigbox = beautifyed_html.find_all("div",{"class" : "_1AtVbE"})

# %%
bigbox[6].div.div.div.a['href']
# Out:
# '/apple-iphone-13-pro-max-gold-1-tb/p/itmdbbad9da2b178?pid=MOBG6VF5GHTNXG9K&lid=LSTMOBG6VF5GHTNXG9KRXWPBP&marketplace=FLIPKART&q=iphone13promax&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=bef050fd-3cf9-4d4a-a33f-e0be6ac53f9a.MOBG6VF5GHTNXG9K.SEARCH&ppt=None&ppn=None&ssid=pyjh037a2o0000001663737954017&qH=082bd912671370dd'

# %%
"https://www.flipkart.com"+ bigbox[6].div.div.div.a['href']

# to reach to that perticular url we have writen the 3 div tags  like(bigbox[6].div.div.div)
# Out:
# 'https://www.flipkart.com/apple-iphone-13-pro-max-gold-1-tb/p/itmdbbad9da2b178?pid=MOBG6VF5GHTNXG9K&lid=LSTMOBG6VF5GHTNXG9KRXWPBP&marketplace=FLIPKART&q=iphone13promax&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=bef050fd-3cf9-4d4a-a33f-e0be6ac53f9a.MOBG6VF5GHTNXG9K.SEARCH&ppt=None&ppn=None&ssid=pyjh037a2o0000001663737954017&qH=082bd912671370dd'

# %%
product6 = "https://www.flipkart.com"+ bigbox[6].div.div.div.a['href']

# %%
product6
# Out:
# 'https://www.flipkart.com/apple-iphone-13-pro-max-gold-1-tb/p/itmdbbad9da2b178?pid=MOBG6VF5GHTNXG9K&lid=LSTMOBG6VF5GHTNXG9KRXWPBP&marketplace=FLIPKART&q=iphone13promax&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=bef050fd-3cf9-4d4a-a33f-e0be6ac53f9a.MOBG6VF5GHTNXG9K.SEARCH&ppt=None&ppn=None&ssid=pyjh037a2o0000001663737954017&qH=082bd912671370dd'

# %%
import requests

# %%
product66=requests.get(product6)

# %%
product6
# Out:
# 'https://www.flipkart.com/apple-iphone-13-pro-max-gold-1-tb/p/itmdbbad9da2b178?pid=MOBG6VF5GHTNXG9K&lid=LSTMOBG6VF5GHTNXG9KRXWPBP&marketplace=FLIPKART&q=iphone13promax&store=tyy%2F4io&srno=s_1_4&otracker=search&fm=organic&iid=bef050fd-3cf9-4d4a-a33f-e0be6ac53f9a.MOBG6VF5GHTNXG9K.SEARCH&ppt=None&ppn=None&ssid=pyjh037a2o0000001663737954017&qH=082bd912671370dd'

# %%
bs(product6,"html.parser") 

# html.parser which create link when we press it, it will take to the prefered link that you are looking for
# Out:
# https://www.flipkart.com/apple-iphone-13-pro-max-gold-1-tb/p/itmdbbad9da2b178?pid=MOBG6VF5GHTNXG9K&amp;lid=LSTMOBG6VF5GHTNXG9KRXWPBP&amp;marketplace=FLIPKART&amp;q=iphone13promax&amp;store=tyy%2F4io&amp;srno=s_1_4&amp;otracker=search&amp;fm=organic&amp;iid=bef050fd-3cf9-4d4a-a33f-e0be6ac53f9a.MOBG6VF5GHTNXG9K.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=pyjh037a2o0000001663737954017&amp;qH=082bd912671370dd

# %%
product66.encoding = 'utf-8'

# %%
bs(product66.text,"html.parser")
# Out:
# <!DOCTYPE html>
# ...

# %%
product6_page = bs(product66.text,"html.parser")

# %%
product6_page.find_all('div',{"class": "_1AtVbE col-12-12"})
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1iyjIJ"><div class="_3li7GG"><div class="_35DpL-"><div class="_2FHWw4"><div class="_2mLllQ" style="height:640px"><ul class="_3GnUWp" style="-webkit-transform:translateY(-0px);-moz-transform:translateY(-0px);-o-transform:translateY(-0px);-ms-transform:translateY(-0px);transform:translateY(-0px)"><li class="_20Gt85 _1Y_A6W" style="height:64px"><div class="_1AuMiq P9aMAP"><div class="_2E1FGS"><img class="q6DClP" src="https://rukminim1.flixcart.com/image/128/128/ktketu80/mobile/6/v/c/iphone-13-pro-max-mllh3hn-a-apple-original-imag6vpgpycue85h.jpeg?q=70"/></div></div></li><li class="_20Gt85 _1Y_A6W" style="height:64px"><div class="_1AuMiq"><div class="_2E1FGS"><img class="q6DClP" src="https://rukminim1.flixcart.com/image/128/128/ktketu80/mobile/6/v/c/iphone-13-pro-max-mllh3hn-a-apple-original-imag6vpgpycue85h.jpeg?q=70"/></div><div class="_2usHgU"></div><div class="_3g-Cpg"></div></div></li><li class="_20Gt85 _1Y_A6W" style="height:64px"><div c
# ...

# %%
price = product6_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})

# %%
price
# Out:
# [<div class="_30jeq3 _16Jk6d">₹1,79,900</div>]

# %%
price = all_review[0].text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 price = all_review[0].text
#
# NameError: name 'all_review' is not defined

# %%
price
# Out:
# [<div class="_30jeq3 _16Jk6d">₹1,79,900</div>]

# %%
product6_page.find_all('div',{"class":"_1AtVbE col-12-12"})
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1iyjIJ"><div class="_3li7GG"><div class="_35DpL-"><div class="_2FHWw4"><div class="_2mLllQ" style="height:640px"><ul class="_3GnUWp" style="-webkit-transform:translateY(-0px);-moz-transform:translateY(-0px);-o-transform:translateY(-0px);-ms-transform:translateY(-0px);transform:translateY(-0px)"><li class="_20Gt85 _1Y_A6W" style="height:64px"><div class="_1AuMiq P9aMAP"><div class="_2E1FGS"><img class="q6DClP" src="https://rukminim1.flixcart.com/image/128/128/ktketu80/mobile/6/v/c/iphone-13-pro-max-mllh3hn-a-apple-original-imag6vpgpycue85h.jpeg?q=70"/></div></div></li><li class="_20Gt85 _1Y_A6W" style="height:64px"><div class="_1AuMiq"><div class="_2E1FGS"><img class="q6DClP" src="https://rukminim1.flixcart.com/image/128/128/ktketu80/mobile/6/v/c/iphone-13-pro-max-mllh3hn-a-apple-original-imag6vpgpycue85h.jpeg?q=70"/></div><div class="_2usHgU"></div><div class="_3g-Cpg"></div></div></li><li class="_20Gt85 _1Y_A6W" style="height:64px"><div c
# ...

# %%
rating = product6_page.find_all('div',{"class":"_1AtVbE col-12-12"})

# %%
rating
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1iyjIJ"><div class="_3li7GG"><div class="_35DpL-"><div class="_2FHWw4"><div class="_2mLllQ" style="height:640px"><ul class="_3GnUWp" style="-webkit-transform:translateY(-0px);-moz-transform:translateY(-0px);-o-transform:translateY(-0px);-ms-transform:translateY(-0px);transform:translateY(-0px)"><li class="_20Gt85 _1Y_A6W" style="height:64px"><div class="_1AuMiq P9aMAP"><div class="_2E1FGS"><img class="q6DClP" src="https://rukminim1.flixcart.com/image/128/128/ktketu80/mobile/6/v/c/iphone-13-pro-max-mllh3hn-a-apple-original-imag6vpgpycue85h.jpeg?q=70"/></div></div></li><li class="_20Gt85 _1Y_A6W" style="height:64px"><div class="_1AuMiq"><div class="_2E1FGS"><img class="q6DClP" src="https://rukminim1.flixcart.com/image/128/128/ktketu80/mobile/6/v/c/iphone-13-pro-max-mllh3hn-a-apple-original-imag6vpgpycue85h.jpeg?q=70"/></div><div class="_2usHgU"></div><div class="_3g-Cpg"></div></div></li><li class="_20Gt85 _1Y_A6W" style="height:64px"><div c
# ...

# %%
len(rating)
# Out:
# 19

# %%
product6_page.find_all('div',{"class":"_3LWZlK _1BLPMq"})[1].text
# Out:
# '5'

# %%
product_rating = product6_page.find_all('div',{"class":"_3LWZlK _1BLPMq"})[1].text

# %%
product_rating
# Out:
# '5'

# %%
product6_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})
# Out:
# [<div class="_30jeq3 _16Jk6d">₹1,79,900</div>]

# %%
product_price= product6_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})

# %%
product_price
# Out:
# [<div class="_30jeq3 _16Jk6d">₹1,79,900</div>]

# %%
len(product_price)
# Out:
# 1

# %%
product_price= product6_page.find_all('div',{"class":"_30jeq3 _16Jk6d"})[0].text

# %%
product_price
# Out:
# '₹1,79,900'

# %%
all_comments  = product6_page.find_all('div',{"class":"t-ZTKy"})

# %%
len(all_comments)
# Out:
# 10

# %%
all_comments[0].text
# Out:
# 'It works really well More than anything I enjoy flaunting my three eyed phone and Apple 🍎 Logo ! Of course it’s a costly phone and I won’t justify its price tag . Still Superb Display Great Camera Two day Battery life and pure luxury of using an iPhone I like that ! At last … If u don’t have a iPhone you don’t have a iPhone 📱READ MORE'

# %%
all_comments[0].text
# Out:
# 'It works really well More than anything I enjoy flaunting my three eyed phone and Apple 🍎 Logo ! Of course it’s a costly phone and I won’t justify its price tag . Still Superb Display Great Camera Two day Battery life and pure luxury of using an iPhone I like that ! At last … If u don’t have a iPhone you don’t have a iPhone 📱READ MORE'

# %%
for i in product6_page:
    product_price
    product_rating
    all_comments[0].text
    print(product_price,product_rating,all_comments[0].text)
# Out:
# ₹1,79,900 5 It works really well More than anything I enjoy flaunting my three eyed phone and Apple 🍎 Logo ! Of course it’s a costly phone and I won’t justify its price tag . Still Superb Display Great Camera Two day Battery life and pure luxury of using an iPhone I like that ! At last … If u don’t have a iPhone you don’t have a iPhone 📱READ MORE
# ₹1,79,900 5 It works really well More than anything I enjoy flaunting my three eyed phone and Apple 🍎 Logo ! Of course it’s a costly phone and I won’t justify its price tag . Still Superb Display Great Camera Two day Battery life and pure luxury of using an iPhone I like that ! At last … If u don’t have a iPhone you don’t have a iPhone 📱READ MORE
